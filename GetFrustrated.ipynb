# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib

font = {'family' : 'normal',
        'size'   : 24}

matplotlib.rc('font', **font)

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 8)

# %matplotlib inline

# %%
data = pd.read_csv('error_message_data_v2.csv')
# Out:
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
#get rid of empty queries
data = data.dropna(subset=['raw_source'])

# %%
#here I put the times into python's datetime

import datetime as dt

def get_time(Modedt):
    try:
        year = Modedt[:4]
        month = Modedt[5:7]
        day  = Modedt[8:10]
        hour  = Modedt[11:13]
        minute  = Modedt[14:16]
        sec  = Modedt[17:19]
        micsec  = Modedt[20:23]
        return dt.datetime(int(year), int(month), int(day), int(hour), int(minute), int(sec), int(micsec)*1000)
    except TypeError:
        #print Modedt
        return float('nan')
    
print get_time(data['created_at'].iloc[0])

#sometimes Completed_at = nan 
data['createdT'] = data['created_at'].apply(get_time)
data['completedT'] = data['completed_at'].apply(get_time)
data['deltaTime'] = (data['completedT']-data['createdT'])
# Out:
# 2013-11-14 02:24:06.940000

# %%
#get intermediate user data only (
minQueries = 10
maxQueries = 1000
UserQueryCount = data['executed_by_id'].value_counts()
UserQueryCount = UserQueryCount[UserQueryCount >= minQueries]
UserQueryCount = UserQueryCount[UserQueryCount < maxQueries]
intermediateUsers = UserQueryCount.index.values
def isintermediateUser(userid):
    if userid in intermediateUsers:
        return True
    else:
        return False

data['isIntermediate'] = data['executed_by_id'].apply(isintermediateUser)
intermediateUserData = data[data['isIntermediate']]

# %%
userList = intermediateUserData['executed_by_id'].unique()

# %%
len(userList)
# Out:
# 1466

# %%
intermediateUserData
# Out:
#       id error_message error_detail  executed_by_id  report_id  \
# 169  134           NaN          NaN               8         37
# 170  135           NaN          NaN               8         37
# 172  137           NaN          NaN               8         37
# 176  141           NaN          NaN               8         37
# 177  533           NaN          NaN               8         37
# 179  535           NaN          NaN               8         37
# 223  221           NaN          NaN              18         55
# 224  222           NaN          NaN              18         55
# 284  248           NaN          NaN              18         65
# 302  261           NaN          NaN              18         68
#      ...           ...          ...             ...        ...
#
#                    created_at              completed_at     parameters
# 169  2013-11-18T01:40:45.533Z  2013-11-18T01:40:47.524Z  {"limit":100} ...
# 170  2013-11-18T01:43:25.791Z  2013-11-18T01:43:27.806Z  {"limit":100} ...
# 172  2013-11-18T01:44:06.773Z  2013-11-18T01:44:08.592Z  {"limit":100} ...
# 176  2013-11-18T01:46:07.441Z  2013-11-18T01:46:09.217Z  {"limit":100} ...
# 177  2013-11-29T06:58:49.622Z  2013-11-29T06:58:51.630Z  {"limit":100} ...
# 179  2013-11-29T06:59:36.238Z  2013-11-29T06:59:38.158Z  {"limit":100} ...
# 223  2013-11-20T00:17:59.700Z  2013-11-20T00:18:01.493Z  {"limit":100} ...
# 224  2013-11-20T00:18:37.343Z  2013-11-20T00:18:39.052Z  {"limit":100} ...
# 284  2013-11-20T00:39:54.898Z  2013-11-20T00:39:56.805Z  {"limit":100} ...
# 302  2013-11-20T01:28:44.410Z  2013-11-20T01:28:46.280Z  {"limit":100} ...
#                           ...                       ...            ...
#
# [185717 rows x 16 columns]

# %%
usersLastQuery = []
for user in userList:
    usersQueries = intermediateUserData[intermediateUserData['executed_by_id']==user]
    lastQueryTime = max(usersQueries['createdT'])
    #print lastQueryTime
    usersLastQuery.append(usersQueries[usersQueries['createdT']==lastQueryTime]['id'].values[0])

# %%
usersQueries.sort(columns = ['createdT'])['createdT']
# Out:
# 370456   2015-01-19 16:27:32.341000
# 370453   2015-01-19 16:28:04.963000
# 370457   2015-01-19 16:30:35.566000
# 370455   2015-01-19 16:57:41.238000
# 370454   2015-01-19 16:58:41.825000
# 370469   2015-01-19 16:59:22.206000
# 370468   2015-01-19 16:59:45.701000
# 370460   2015-01-19 17:45:30.225000
# 370459   2015-01-19 17:46:19.530000
# 370458   2015-01-19 17:47:06.418000
# Name: createdT, dtype: datetime64[ns]

# %%
435291 in usersLastQuery
# Out:
# True

# %%
len(usersLastQuery)
# Out:
# 1466

# %%
lastQueries = intermediateUserData[intermediateUserData['id'].apply(lambda x: x in usersLastQuery)]

# %%
def getYearMonth(timestamp):
    return dt.date(timestamp.year, timestamp.month, 15)

lastQueries['YearMonth'] = lastQueries['createdT'].apply(getYearMonth)
intermediateUserData['YearMonth'] = intermediateUserData['createdT'].apply(getYearMonth)

# %%
numQueries = lastQueries['YearMonth'].value_counts()
numQueries = numQueries.sort_index()

#Number of queries of people that 
numQueries.plot(kind="bar", color = 'k', figsize = (8, 5), grid=False)

monthList = ['Nov 2013', 'Dec 2013', 'Jan 2014', 'Feb 2014', 'Mar 2014', 'Apr 2014', 'May 2014', 'Jun 2014', 'Jul 2014', 'Aug 2014', 'Sep 2014', 'Oct 2014', 'Nov 2014', 'Dec 2014', 'Jan 2015']
plt.xlabel('Time')
plt.ylabel('Last Queries')
plt.xticks(np.arange(0.75, 13.75), monthList[-len(numQueries):])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9e3f503410>,
#   <matplotlib.axis.XTick at 0x7f9e3f37a9d0>,
#   <matplotlib.axis.XTick at 0x7f9e38e6ba50>,
#   <matplotlib.axis.XTick at 0x7f9e38e6b250>,
#   <matplotlib.axis.XTick at 0x7f9e38eb9750>,
#   <matplotlib.axis.XTick at 0x7f9e38eb9d10>,
#   <matplotlib.axis.XTick at 0x7f9e38eb5950>,
#   <matplotlib.axis.XTick at 0x7f9e38eb5450>,
#   <matplotlib.axis.XTick at 0x7f9e38ea1e90>,
#   <matplotlib.axis.XTick at 0x7f9e38ea1550>,
#   <matplotlib.axis.XTick at 0x7f9e38ef9dd0>,
#   <matplotlib.axis.XTick at 0x7f9e38ef93d0>,
#   <matplotlib.axis.XTick at 0x7f9e3f36ea90>],
#  <a list of 12 Text xticklabel objects>)

# %%
numQueries = intermediateUserData['YearMonth'].value_counts()/sum(intermediateUserData['YearMonth'].value_counts())
numQueries = numQueries.sort_index()

#Number of queries of people that 
numQueries.plot(kind="bar", color = 'k', figsize = (8, 5), grid=False)

monthList = ['Nov 2013', 'Dec 2013', 'Jan 2014', 'Feb 2014', 'Mar 2014', 'Apr 2014', 'May 2014', 'Jun 2014', 'Jul 2014', 'Aug 2014', 'Sep 2014', 'Oct 2014', 'Nov 2014', 'Dec 2014', 'Jan 2015']
plt.xlabel('Time')
plt.ylabel('Last Queries')
plt.xticks(np.arange(0.75, 15.75), monthList)
# Out:
# ([<matplotlib.axis.XTick at 0x7f9e3f2e9210>,
#   <matplotlib.axis.XTick at 0x7f9e3f2a28d0>,
#   <matplotlib.axis.XTick at 0x7f9e3f52b890>,
#   <matplotlib.axis.XTick at 0x7f9e3f52b350>,
#   <matplotlib.axis.XTick at 0x7f9e3f52ac90>,
#   <matplotlib.axis.XTick at 0x7f9e3f529c90>,
#   <matplotlib.axis.XTick at 0x7f9e3f529390>,
#   <matplotlib.axis.XTick at 0x7f9e3f528c50>,
#   <matplotlib.axis.XTick at 0x7f9e3f528050>,
#   <matplotlib.axis.XTick at 0x7f9e3f527c10>,
#   <matplotlib.axis.XTick at 0x7f9e3f527050>,
#   <matplotlib.axis.XTick at 0x7f9e3f526c10>,
#   <matplotlib.axis.XTick at 0x7f9e3f525e10>,
#   <matplotlib.axis.XTick at 0x7f9e3f525910>,
#   <matplotlib.axis.XTick at 0x7f9e3f524fd0>],
#  <a list of 15 Text xticklabel objects>)

# %%
#left November or before
leftUsers = lastQueries[lastQueries['YearMonth']<dt.date(2014, 11, 15)]['executed_by_id'].values
rightUsers = lastQueries[lastQueries['YearMonth']>=dt.date(2014, 11, 15)]['executed_by_id'].values

# %%
print len(leftUsers)
print len(rightUsers)
# Out:
# 653
# 813

# %%
#df = 0
#df = pd.DataFrame(columns = intermediateUserData.columns)
#for user in intermediateUserData['executed_by_id'].unique():
#    dataSubset = intermediateUserData[intermediateUserData['executed_by_id'] == user]
#    for uniqueQuery in dataSubset['raw_source'].unique():
 #       querySet = dataSubset[dataSubset['raw_source']==uniqueQuery]
 #       minTime = min(querySet['createdT'])
 #       df = pd.concat([df, querySet[querySet['createdT']==minTime]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-d24d71f073f5> in <module>()
#       6         querySet = dataSubset[dataSubset['raw_source']==uniqueQuery]
#       7         minTime = min(querySet['createdT'])
# ----> 8         df = pd.concat([df, querySet[querySet['createdT']==minTime]])
#
# /usr/lib/python2.7/dist-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     928                        keys=keys, levels=levels, names=names,
#     929                        verify_integrity=verify_integrity)
# --> 930     return op.get_result()
#     931
#     932
#
# /usr/lib/python2.7/dist-packages/pandas/tools/merge.pyc in get_result(self)
#    1021             new_data = self._get_concatenated_data()
#    1022             new_data = self._post_merge(new_data)
# -> 1023             return self.objs[0]._from_axes(new_data, self.new_axes)
#    1024
#    1025     def _post_merge(self, data):
#
# /usr/lib/python2.7/dist-packages/pandas/core/generic.pyc in _from_axes(cls, data, axes)
#     280                 axes = axes[::-1]
#     281             d = cls._construct_axes_dict_from(cls, axes, copy=False)
# --> 282             return cls(data, **d)
#     283
#     284     def _get_axis_number(self, axis):
#
# /usr/lib/python2.7/dist-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     199                                  dtype=dtype, copy=copy)
#     200         elif isinstance(data, dict):
# --> 201             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     202         elif isinstance(data, ma.MaskedArray):
#     203             import numpy.ma.mrecords as mrecords
#
# /usr/lib/python2.7/dist-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     321
#     322         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 323                               dtype=dtype)
#     324
#     325     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /usr/lib/python2.7/dist-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    4466
#    4467     # don't force copy because getting jammed in an ndarray anyway
# -> 4468     arrays = _homogenize(arrays, index, dtype)
#    4469
#    4470     # from BlockManager perspective
#
# /usr/lib/python2.7/dist-packages/pandas/core/frame.pyc in _homogenize(data, index, dtype)
#    4775
#    4776             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 4777                                 raise_cast_failure=False)
#    4778
#    4779         homogenized.append(v)
#
# /usr/lib/python2.7/dist-packages/pandas/core/series.pyc in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2543             # e.g. indexes can have different conversions (so don't fast path them)
#    2544             # GH 6140
# -> 2545             subarr = _try_cast(data, not isinstance(data, Index))
#    2546
#    2547         if copy:
#
# /usr/lib/python2.7/dist-packages/pandas/core/series.pyc in _try_cast(arr, take_fast_path)
#    2509
#    2510         try:
# -> 2511             arr = _possibly_cast_to_datetime(arr, dtype)
#    2512             subarr = pa.array(arr, dtype=dtype, copy=copy)
#    2513         except (ValueError, TypeError):
#
# /usr/lib/python2.7/dist-packages/pandas/core/common.pyc in _possibly_cast_to_datetime(value, dtype, coerce)
#    1726                 v = [v]
#    1727             if len(v):
# -> 1728                 inferred_type = lib.infer_dtype(v)
#    1729                 if inferred_type in ['datetime', 'datetime64']:
#    1730                     try:
#
# KeyboardInterrupt:

# %%
userList = data['executed_by_id'].unique()

frac_Tutorial = {}
num_Tutorial = {}
for user in userList:
    userData = data[data['executed_by_id'] == user]
    if len(userData)>0:
        frac_Tutorial[user] = float(len(userData[userData['public']==True]))/len(userData)
        num_Tutorial[user] = len(userData[userData['public']==True])
    else:
        frac_Tutorial[user] = None 
        num_Tutorial[user] = None

# %%
print float(np.sum(np.array(frac_Tutorial.values())==1))/len(frac_Tutorial.values())
print '75% of intermediate users have only queried tutorial data sets'
print '85.8% of all users have only queried tutorial data sets'
# Out:
# 0.858052533829
# 75% of intermediate users have only queried tutorial data sets
# 85.8% of all users have only queried tutorial data sets

# %%
fracErrorsVec = []
for howManyRecentQuerries in range(1, 11): 
    #howManyRecentQuerries = 1
    recentQueriesOfQuitters = 0
    recentQueriesOfQuitters = pd.DataFrame(columns = lastQueries.columns)
    leftUserTutFrac = []
    
    for user in leftUsers:
        usersQueries = intermediateUserData[intermediateUserData['executed_by_id']==user]
        usersQueries = usersQueries.sort(columns = ['createdT'])
        leftUserTutFrac.append(frac_Tutorial[user])
        #print usersQueries['createdT'][-10:]
        recentQueriesOfQuitters = pd.concat([recentQueriesOfQuitters, usersQueries[-howManyRecentQuerries:]])
        #print len(recentQueriesOfQuitters)
        #usersLastQuery.append(usersQueries[usersQueries['createdT']==lastQueryTime]['id'].values[0])
    
    
    fracErrorsVec.append(float(len(recentQueriesOfQuitters.dropna(subset = ['error_message'])))/len(recentQueriesOfQuitters))
        
        
    rightUserTutFrac = []
    for user in rightUsers:
        rightUserTutFrac.append(frac_Tutorial[user])

fracErrorsVec.reverse()

# %%
plt.plot(range(10),fracErrorsVec)

# %%
np.mean(np.array(leftUserTutFrac))
# Out:
# 0.88539694244718359

# %%
plt.hist(leftUserTutFrac, bins=20)
# Out:
# (array([  49.,   10.,    6.,    4.,    1.,    2.,    3.,    1.,    1.,
#           1.,    0.,    2.,    0.,    1.,    1.,    2.,    1.,    0.,
#           1.,  567.]),
#  array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,
#         0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,
#         0.9 ,  0.95,  1.  ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(rightUserTutFrac, bins = 20)
# Out:
# (array([ 166.,   28.,   17.,   12.,    7.,    6.,    1.,    3.,    3.,
#           2.,    3.,    3.,    3.,    3.,    1.,    1.,    6.,    1.,
#           2.,  545.]),
#  array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,
#         0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,
#         0.9 ,  0.95,  1.  ]),
#  <a list of 20 Patch objects>)

# %%
#fraction of errors in last 10 of quitters
print 'frac errors: ' + str(float(len(recentQueriesOfQuitters.dropna(subset = ['error_message'])))/len(recentQueriesOfQuitters))
print 'frac tutori: ' + str(float(len(recentQueriesOfQuitters[recentQueriesOfQuitters['public']]))/len(recentQueriesOfQuitters))
# Out:
# frac errors: 0.0750382848392
# frac tutori: 0.883614088821

# %%
len(recentQueriesOfQuitters)
# Out:
# 653

# %%
peopleToSave = recentQueriesOfQuitters[recentQueriesOfQuitters['public']==False]
float(len(peopleToSave.dropna(subset = ['error_message'])))/len(peopleToSave)
# Out:
# 0.14473684210526316

# %%
# %run errorClassifier.py
recentQueriesOfQuitters['Error Class'] = recentQueriesOfQuitters['error_message'].dropna().apply(identErr2)
fig = plt.figure(figsize = (8, 5))

font = {'family' : 'normal',
        'size'   : 18}
matplotlib.rc('font', **font)

(recentQueriesOfQuitters['Error Class'].value_counts()[:20]/sum(recentQueriesOfQuitters['Error Class'].value_counts())).plot(kind='bar', figsize=(20, 4))
# Out:
# rare errors
# no error
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=18.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
