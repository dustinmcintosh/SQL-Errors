# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib

font = {'family' : 'normal',
        'size'   : 24}

matplotlib.rc('font', **font)

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 8)

# %matplotlib inline

data = pd.read_csv('error_message_data_v2.csv')

sqlKeywords = pd.read_csv('keywords.txt', names = '1').dropna().values.tolist()
print sqlKeywords[:5]
print len(sqlKeywords)
# Out:
# [['ADD'], ['EXCEPT'], ['PERCENT'], ['ALL'], ['EXEC']]
# 173
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
# %run errorClassifier.py
data['Error Class'] = data['error_message'].apply(identErr2)
# Out:
# rare errors
# no error

# %%
#df = random subset of 1000 of the errors
import random
rows = random.sample(data.index, 10000)
df = data.ix[rows]
df = df.dropna()

# %%
#Count each keyword in each query
import re

for keyword in sqlKeywords:
    
    keyToSearch = keyword[0].lower()
    #print keyToSearch
    def getCount(SQLquery):
        queryParse = re.findall(r"[\w']+|[.,!?'\";:)(]", SQLquery.lower())
        return queryParse.count(keyToSearch)
    
    df[keyToSearch] = df['raw_source'].apply(getCount)

# %%
df.iloc[:,12:]
# Out:
#                     Error Class  add  except  percent  all  exec  plan  alter  \
# 226877           unknown column    0       0        0    0     0     0      0
# 288865  unknown table or schema    0       0        0    0     0     0      0
# 76730               FROM syntax    0       0        0    0     0     0      0
# 223831   unknown error occurred    0       0        0    0     0     0      0
# 61429            unknown column    0       0        0    0     0     0      0
# 198345        misc syntax error    0       0        0    0     0     0      0
# 355908     data of invalid type    0       0        0    0     0     0      0
# 204130  must appear in group by    0       0        0    0     0     0      0
# 151980           Internal Error    0       0        0    0     0     0      0
# 256136  operator does not exist    0       0        0    0     0     0      0
#                             ...  ...     ...      ...  ...   ...   ...    ...
#
#
# 226877 ...
# 288865 ...
# 76730  ...
# 223831 ...
# 61429  ...
# 198345 ...
# 355908 ...
# 204130 ...
# 151980 ...
# 256136 ...
#
# [2208 rows x 173 columns]

# %%
#This is not correct as "in" is a substring of "having". for example

fig = plt.figure(figsize = (8, 5))

font = {'family' : 'normal',
        'size'   : 18}
matplotlib.rc('font', **font)

frequencies = df.iloc[:, 13:].sum()
frequencies = frequencies[frequencies>0]/float(sum(frequencies))
frequencies.sort(ascending=False)

frequencies[:30].plot(kind="bar", figsize=(17, 5))

# %%
df.iloc[:, 13:]
# Out:
#         add  except  percent  all  exec  plan  alter  execute
# 73258     0       0        0    0     0     0      0        0 ...
# 186750    0       0        0    0     0     0      0        0 ...
# 361066    0       0        0    0     0     0      0        0 ...
# 322046    0       0        0    0     0     0      0        0 ...
# 366248    0       0        0    0     0     0      0        0 ...
# 219696    0       0        0    0     0     0      0        0 ...
# 229457    0       0        0    0     0     0      0        0 ...
# 319849    0       0        0    0     0     0      0        0 ...
# 244788    0       0        0    0     0     0      0        0 ...
# 301580    0       0        0    0     0     0      0        0 ...
#         ...     ...      ...  ...   ...   ...    ...      ...
#
# [231 rows x 172 columns]
